# %%
 # list  alpha , int , floot , boolean

# %%
name1 = "ali"
name2 = "adnan"
name3 = "amjad" 
name4= "ahmed" 

names = ["ali","adnan","amjad","ahmed"] # index number  0 ali , 1 adnan , 2 amjad 3 ahmed
  
print(names[2])
# Out:
# amjad

# %%
print(names[3])
# Out:
# ahmed

# %%
a = ["ali", 12, 23.5, "Ture"]
print(a)
# Out:
# ['ali', 12, 23.5, 'Ture']

# %%
pet = ["cow","cat","dog","goat","camel","snake"]
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'goat', 'camel', 'snake']

# %%
pet.append("sheep")  # append mean add the word for list

# %%
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'goat', 'camel', 'snake', 'sheep', 'sheep']

# %%
pet.insert(3,"fish") # insert mai hum kahi bhi koi bhi value kahi bhi  add kar sahkthy hai

# %%
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'fish', 'goat', 'camel', 'snake', 'sheep', 'sheep']

# %%
#  ya silice ka method hai is mai hum value 2:5 , 1:4 aisi daithy hai tu ya in number kai hesaab sai ki output daita hai

newpet = pet[2:5
]
print(newpet)
# Out:
# ['dog', 'fish', 'goat']

# %%
pet2 = pet[2:7]
print(pet2)
# Out:
# ['dog', 'fish', 'goat', 'camel', 'snake']

# %%
# delete the method of del

del pet[4]
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'fish', 'sheep', 'sheep']

# %%
# remove the word

pet.remove("sheep")

# %%
print(pet)
# Out:
# ['cow', 'cat', 'dog', 'fish']

# %%
x = "hello, my name is hamza"

# %%
# replace value nikal kar koi or value daltha hai

y = x.replace("my","you")

# %%
print(y)
# Out:
# hello, you name is hamza

# %%
# pop last element nikaltha haii

pet3 = pet.pop()

# %%
print(pet3)
# Out:
# cat

# %%
print(names)
# Out:
# ['ali', 'adnan', 'amjad', 'ahmed']

# %%
# tapple mai koi bhi cheez change nahi hothi hai .


subject = ("eng","isl","maths","urdu","comp")

# %%
print(subject)
# Out:
# ('eng', 'isl', 'maths', 'urdu', 'comp')
